# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/AI systems Project/SummarIQ')

# %%
cd /content/drive/MyDrive/AI systems Project/SummarIQ
# Out:
# /content/drive/MyDrive/AI systems Project/SummarIQ

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')
from pandas.plotting import scatter_matrix
from extractor.latex_extractor import LatexExtractor
# from pdf_conversion import PDFExtractor
# import torch
# import tf_keras as keras
# from transformers import pipeline
import re

# %%
extractor = LatexExtractor(
    folder_path="/Applications/AI Systems project Data/Test_pdf",
    output_path="latex_extracted.json"
)


extractor.process_all_files()

extractor.save_to_json()
# Out:
# Saved to latex_extracted.json

# %%
latexfiles_df = pd.read_json("latex_extracted.json")
latexfiles_df
# Out:
#   file_name                                             title  \
# 0    sm.tex  Computations and ML for surjective rational maps
#
#               authors                                           abstract  \
# 0  [Ilya Karzhemanov]  The present note studies \n$f: ^2  ^2$ with \n...
#
#                                             sections  \
# 0  [{'name': 'Introduction', 'content': '
#
#
#
#
#
# Le...
#
#                                            equations  \
# 0  [\label{diag} \xymatrix{\n& X \ar[dl]_\varphi ...
#
#                                            full_text
# 0  [14pt]amsart\n[T1]fontenc\n[utf8]inputenc\n\n ...

# %%
def prepare_input(row):
    text = row["text"]
    equations = row["equations"]
    combined = f"Paper Text:\n{text}\n\nEquations:\n{equations}"
    return combined

# %%
latexfiles_df["input_text"] = latexfiles_df.apply(prepare_input, axis=1)
latexfiles_df
# Out:
#                                 file_id file_name             authors  \
# 0  0087b54c-53c1-4fc5-ac2f-f9a5042def8d    sm.tex  [Ilya Karzhemanov]
#
#                                               title  \
# 0  Computations and ML for surjective rational maps
#
#                                                 text  \
# 0  The present note studies $f: ^2 ^2$ with terms...
#
#                                            equations  \
# 0  [\label{diag} \xymatrix{\n& X \ar[dl]_\varphi ...
#
#                                           input_text
# 0  Paper Text:\nThe present note studies $f: ^2 ^...

# %%
latexfiles_df['input_text']
# Out:
# 0    Paper Text:\nThe present note studies $f: ^2 ^...
# Name: input_text, dtype: object

# %%
from transformers import BartTokenizer, BartForConditionalGeneration

# %%
tokenizer = BartTokenizer.from_pretrained("facebook/bart-large-cnn")
model = BartForConditionalGeneration.from_pretrained("facebook/bart-large-cnn")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]

# %%
summarizer = pipeline(
    "text2text-generation",
    model="facebook/bart-large-cnn",
    framework="pt",
    device=-1
)
# Out:
# Device set to use cpu

# %%
def make_prompt(text, equations=None):
    eq_text = "\n".join(equations) if equations else "None"
    prompt = f"""
Summarize the following scientific text in **sections** with the titles:
Core Idea, Why it matters, Methodology, Important Equations, Results, Limitations, Impact.

Provide each section clearly, e.g.:

Core Idea:
<text>

Why it matters:
<text>

...

Important Equations:
<list equations here>

Text:
{text}

Equations:
{eq_text}
"""
    return prompt

# %%
def structured_summary(text, equations):
    prompt = make_prompt(text, equations)
    # Truncate to avoid too long input
    prompt = prompt[:2000]  # adjust length if needed

    try:
        summary_output = summarizer(prompt, max_length=400, min_length=100, do_sample=False)
        summary_text = summary_output[0].get('summary_text') or summary_output[0].get('generated_text')

        # Split into sections
        sections = {}
        current_section = None
        for line in summary_text.split("\n"):
            line = line.strip()
            if not line:
                continue
            # Check if line starts with section
            if ":" in line:
                sec_name, sec_text = line.split(":", 1)
                sec_name = sec_name.strip()
                sec_text = sec_text.strip()
                sections[sec_name] = sec_text
                current_section = sec_name
            elif current_section:
                # append remaining lines to the last section
                sections[current_section] += " " + line

        return sections

    except Exception as e:
        print("Error summarizing:", e)
        return {}

# %%
for i, row in latexfiles_df.iterrows():
  print(row["text"])
  print(row["equations"])
# Out:
# The present note studies $f: ^2 ^2$ with terms and the indeterminacy locus $I_f $. We develop an experimental approach, based on some Python programming and Machine Learning, towards the classification of such maps; a couple of new explicit $f$ is constructed in this way. We also prove (via pure projective geometry) that a general non-regular cubic endomorphism $f$ of $^2$ is surjective if and only if the set $I_f$ has cardinality at least $3$. Let $X$ be a complex projective variety and $f: X X$ its rational endomorphism. Denote by $I_f X$ the (closed) indeterminacy locus of $f$. Then $f$ is called if the induced morphism $X I_f X$ is onto. Such maps were introduced and studied --- from the algebro-geometric point of view --- in the paper (with $X$ being a projective space $^n$). The initial motivation for this study came from the optimal control theory and mathematical genetics. Later a relation of surjective rational maps with algebraic statistics and quantization has also been realized (see and ). Another classical subject here is holomorphic dynamics: the given $f$ is very much akin to a (see ); hence one could try to define dynamical degrees of $f$ (with respect to some K "ahler form on $X$) and (re)prove standard relations between them and the entropy (cf. ). In the present note, we concentrate on the behavior of surjective maps in families, aiming to show that for certain rational maps the surjectivity is a. Namely, let us take $X = ^2$, so that in projective coordinates any of its rational endomorphisms looks like this: $$ f = f_0: f_1: f_2: ^2 ^2, $$ where $f_i$ are mutually coprime homogeneous polynomials of some degree $d$. These polynomials span a plane $$ in the linear system $|_ ^2 (d)|$ of all degree $d$ curves on $^2$. . Note that $I_f ^2$ is given by equations $f_0 = f_1 = f_2 = 0$. Then the morphism $f: ^2 I_f ^2$ can be defined in the following coordinate-free way (): for any point $ x ^2 I_f$, consider the pencil $ $ of all linear combinations of $f_i$, which vanish at $ x $; now identify $^2$ with the dual plane $^*$ of lines and put $$ f: x ^2 = ^*. $$ So the term, when applied to the map $f$, simply means that the corresponding plane $ |_ ^2 (d)|$ is such (or, if being more formal, one may state genericity in terms of points on the relevant Grassmannian). Further, the $0$-scheme $I_f$ varies together with $f$, of course, and one can always achieve $I_f = $ for appropriate $f_i$. Hence the map $f$ becomes and its surjectivity is straightforward. Thus, in order to have a fruitful problem here, let us fix a (generic) set $I_f$, consider the maximal linear system $ |_ ^2 (d)|$ with the base locus $() = I_f$, and treat only those planes $$, which belong to $$. In this setting, the generality problem has been solved completely in for the case, i. e. when $d = 2$. More precisely, asserts that for every given cardinality $ #I_f$ the set of all $ $, defining surjective maps, is (including the set $$). Presently, we consider the next, , case of $d = 3$. Our aim is two-fold. Firstly, we extend the main result of by showing that all such surjective $f$, with fixed generic $I_f$, form an open set (see Section~ below). Secondly, we develop an experimental approach towards a complete description of (cubic) surjective rational maps, which also yields new examples of them (see Section~). Surjectivity property seems like another substitute for the term ``generic'' among many others that one comes across in classical algebraic geometry. For instance, given a smooth conic $(q = 0) ^2$ the set of triples of linear forms $l_i$, satisfying $q = _i l_i^2$, can be compactified into the --- this is a codimension $3$ linear section of the Grassmannian $G(3, 5)$, --- and the self-polarity condition can be effectively verified (see ). Another example is the non-gradient property for a given quadratic endomorphism of $^3$ in terms of smoothness of the Jacobi surface (see ). Coming back to our setting, a rational map $f: ^2 ^2$ is su ...
# ['\\label{diag} \\xymatrix{\n& X \\ar[dl]_\\varphi \\ar[dr]^{\\psi} \\\\\n\\p^2 \\ar@{-->}[rr]^{f} && \\p^2}', '\\label{eq-x-1} x^2(a - x) + x^2(a - x)^2 + 2x(a - x)^2 + 1 + a - x\n- bx(a - x) = 0.', '\\label{q-eq-zer} x^4 + (-2a + 2)x^3 + (a^2 - 4a)x^2 + (2a^2 - a +\nb - 1)x + a^2 + a(1 - b) - b = 0.', 'f = [f_0: f_1: f_2]: \\p^2 \\dashrightarrow \\p^2,', 'f: {\\bf x} \\mapsto \\ell \\in \\p^2 = \\Pi^*.', 'C \\cap Z = \\{P,P_1,P_2,\\ldots,P_7\\}', 'x^2y + y^2z,\\ xy^2 + y^2z,\\ x^2z + y^2z,\\ xyz,\\ xz^2 + yz^2', '[x: y: z] \\mapsto [x^2y + y^2z: xyz: x^2y + xy^2 + 2y^2z + z^2(x +\ny)].', '(x,y) \\mapsto (x + \\frac{y}{x}, x + y + \\frac{2y}{x} + \\frac{1}{x}\n+ \\frac{1}{y})', 'x^2y + xy^2 + 2y^2 + x + y = bxy.', 'x^4 + (1 - 2a)x^3 + (a^2 - 3a + b)x^2 + (2a^2 - ba - 1)x + a + 1 =\n0.', 'x^3 + 2x^2 + (b + 4)x + b + 1 = 0.', "\\text{how to make ``predictions of surjectivity'' for\n\\emph{arbitrary} vectors}\\ \\texttt{v, u, t},\\ \\text{not\nnecessarily over}\\ \\mathbb{F}_p?", 'x^2y + y^2z + z^2(x + y),\\ y^2(x - z),\\ z(x^2 + y^2),\\ xyz + xz^2\n+ yz^2,', '[x: y: z] \\mapsto [x^2y + y^2z + z^2(x + y): y^2(x - z): xyz +\nz^2(x + y)].\\footnote{Here, as in {\\ref{subsection:ex-calc-1}},\nall data is considered over $\\com$. Hence we distinguish $y^2(x -\nz)$ and $y^2(x + z)$ from the initial $\\mathbb{F}_2$-basis of\n$\\Lambda$.}', 'x = z = 1,\\quad \\frac{(y + 1)^2}{2y + 1} = a,\\ y \\ne -0.5.', '(x,y) \\mapsto (\\frac{x^2 + z + xz^2 + z^2}{x - z}, \\frac{xz + xz^2\n+ z^2}{x - z})', '(x,y) \\mapsto (\\frac{x^2 + z - xz}{x - z}, \\frac{xz + z + xz^2 +\nz^2}{x - z}).', 'xz + z + xz^2 + z^2 = b(x - z).']

# %%
structured_summaries = []

for i, row in latexfiles_df.iterrows():
    print(f"Summarizing: {row['file_name']} ...")
    summary_sections = structured_summary(row["text"], row["equations"])
    structured_summaries.append({
        "file_name": row["file_name"],
        "Structured Summary": summary_sections
    })
# Out:
# Summarizing: sm.tex ...

# %%
result_df = pd.DataFrame(structured_summaries)
result_df.to_csv("structured_summaries.csv", index=False)
