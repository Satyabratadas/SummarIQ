# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyabratadas/SummarIQ/blob/master/test_summarize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## not mandatory delete this later

# %%
import os
os.getcwd()
# Out:
# '/Users/satyabrata557/Desktop/AI Systems/SummarIQ/Notebooks'

# %%
import os
os.chdir('/Users/satyabrata557/Desktop/AI Systems/SummarIQ')

# %%
import json
from summarizer.summarizer_base import Summarizer_base

# %%
model_path = "/Applications/AI Projects/t5_base"

# %%
from huggingface_hub import snapshot_download

snapshot_download(
    repo_id="t5-base",
    local_dir=model_path,
    local_dir_use_symlinks=False
)
# Out:
# /opt/anaconda3/envs/satyabrataenv/lib/python3.10/site-packages/huggingface_hub/file_download.py:982: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/537 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# rust_model.ot:   0%|          | 0.00/892M [00:00<?, ?B/s]
# flax_model.msgpack:   0%|          | 0.00/892M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/8.48k [00:00<?, ?B/s]
# ...

# %%
summ = Summarizer_base(model_path="/Applications/AI Projects/t5_base")
# Out:
# Loading T5-Base model on CPU from: /Applications/AI Projects/t5_base

# %%
from transformers import BartTokenizer, BartForConditionalGeneration

model_name = "sshleifer/distilbart-cnn-12-6"
save_path = "models/distilbart"

# Download + save tokenizer
tokenizer = BartTokenizer.from_pretrained(model_name)
tokenizer.save_pretrained(save_path)

# Download + save model weights
model = BartForConditionalGeneration.from_pretrained(model_name)
model.save_pretrained(save_path)

print("Model saved to:", save_path)

# %%
json_path = "/content/drive/MyDrive/AI systems Project/SummarIQ/Text_extractor code/latex_extracted.json"
with open(json_path, "r") as f:
    data = json.load(f)

paper = data[0]

# %%
# paper

# %%
print("\n===== ABSTRACT SUMMARY =====\n")
print(summ.summarize_abstract(paper["abstract"]))

equations = paper.get("equations", [])[:5]

print("\n===== SECTION SUMMARIES =====\n")
for sec in paper["sections"]:
    print(f"\n--- {sec['name']} ---\n")
    print(summ.summarize_section(sec['name'], sec['content'], equations))

print("\n===== EQUATION EXPLANATIONS =====\n")
for i, eq in enumerate(equations, 1):
    print(f"\n--- Equation {i} ---")
    print(eq)
    print("\nExplanation:")
    print(summ.explain_equation(eq))
# Out:
# ===== ABSTRACT SUMMARY =====
#
# We develop an experimental approach, based on some Python programming and Machine Learning, towards the classification of such maps. We also prove (via pure projective geometry) that a general non-regular cubic endomorphism of is surjective if and only if the set has cardinality at least .
#
# ===== SECTION SUMMARIES =====
#
#
# --- Introduction ---
#
# This paper introduces a new theory of surjective rational maps and del Pezzo surfaces. The general idea of the authors' approach is that (surjective) cubic maps can be defined as a vector bundle together with an inclusion , where is a properly defined pull-back (see Section below) and develop an experimental approach towards a complete description of (cubic) rational maps, which also yields new examples of them.
#
# --- Surjectivity results ---
#
# ...

# %%
distil_bart_path = "/Applications/AI Projects/distilbart"

# %%
from transformers import BartTokenizer, BartForConditionalGeneration

model_name = "sshleifer/distilbart-cnn-12-6"
# save_path = distil_bart_path

# Download + save tokenizer
tokenizer = BartTokenizer.from_pretrained(model_name)
tokenizer.save_pretrained(distil_bart_path)

# Download + save model weights
model = BartForConditionalGeneration.from_pretrained(model_name)
model.save_pretrained(distil_bart_path)

print("Model saved to:", distil_bart_path)
